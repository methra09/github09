# %%
# Import additional necessary libraries for ensemble methods
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# We will reuse the 'Sweetness' and 'Crunchiness' dataset (X, y)
# First, ensure data is split and scaled as KNN benefits from it.
# Splitting data (reusing the same split from KNN section for consistency)
X_train_ensemble, X_test_ensemble, y_train_ensemble, y_test_ensemble = train_test_split(X, y, test_size=0.3, random_state=42)

# Scaling features
scaler_ensemble = StandardScaler()
X_train_scaled_ensemble = scaler_ensemble.fit_transform(X_train_ensemble)
X_test_scaled_ensemble = scaler_ensemble.transform(X_test_ensemble)

print("Data split and scaled for ensemble modeling.")
# Out:
# Data split and scaled for ensemble modeling.

# %%
# 1. Logistic Regression
lr = LogisticRegression(random_state=42, solver='liblinear')

# 2. K-Nearest Neighbors
knn = KNeighborsClassifier(n_neighbors=5)

# 3. Decision Tree Classifier
dt = DecisionTreeClassifier(max_depth=3, random_state=42)

print("Individual classifiers defined.")
# Out:
# Individual classifiers defined.

# %%
# Import required libraries
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier

# Create individual models
lr = LogisticRegression(random_state=42)
knn = KNeighborsClassifier(n_neighbors=5)
dt = DecisionTreeClassifier(random_state=42)

# Create a voting classifier
voting_clf = VotingClassifier(
    estimators=[
        ('lr', lr),
        ('knn', knn),
        ('dt', dt)
    ],
    voting='hard'
)

# Train the ensemble model
voting_clf.fit(X_train_scaled_ensemble, y_train_ensemble)

print("Voting Classifier (Hard voting) trained successfully.")
# Out:
# Voting Classifier (Hard voting) trained successfully.

# %%
# Make predictions with the ensemble model
y_pred_ensemble = voting_clf.predict(X_test_scaled_ensemble)

# Evaluate the ensemble model's performance
ensemble_accuracy = accuracy_score(y_test_ensemble, y_pred_ensemble)
ensemble_report = classification_report(y_test_ensemble, y_pred_ensemble)

print(f"Ensemble Model Accuracy: {ensemble_accuracy:.2f}")
print("Ensemble Model Classification Report:\n", ensemble_report)
# Out:
# Ensemble Model Accuracy: 0.94
# Ensemble Model Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95        19
#          1.0       0.94      0.94      0.94        17
#
#     accuracy                           0.94        36
#    macro avg       0.94      0.94      0.94        36
# weighted avg       0.94      0.94      0.94        36
